# %% [markdown]
# ## 从头训练tokenizer的示例
#
# 该notebook提供一个完整的使用[sentencepiece](https://github.com/google/sentencepiece)工具，训练一个BPE算法分词的示例。
#
# SentencePiece是一种基于未经分词的文本进行训练的通用分词工具，由Google开发。它可以用于多种语言，并支持多种分词算法，如BPE（Byte Pair Encoding）和Unigram Language Model。SentencePiece的主要特点和功能如下：
#
# 1. 通用性：SentencePiece可以适用于多种语言，包括英语、中文、日语、韩语等。这使得它成为处理多语言文本和跨语言任务的理想选择。
#
# 1. 未经分词的训练：与传统的分词工具不同，SentencePiece的训练过程不需要经过预分词的文本作为输入。它可以直接训练原始的未经分词的文本，从而更好地捕捉语言的特征和模式。
#
# 1. 分词算法支持：SentencePiece支持多种分词算法，其中最常用的是BPE和Unigram Language Model。BPE算法逐步合并出现频率最高的字符对，而Unigram Language Model则通过学习每个子词的概率分布来进行分词。
#
# 1. 灵活的训练选项：SentencePiece提供了丰富的训练选项，可以控制词汇表大小、分词算法参数等。这使得用户可以根据具体任务和需求进行定制化的分词训练。
#
# 1. 易用的API：SentencePiece提供了多种编程语言的API接口，包括Python、C++、Java等。这使得开发人员可以方便地在各种NLP框架和应用中使用SentencePiece。
#
# 1. 预训练模型和共享模型：SentencePiece提供了一些预训练的模型，可以用于快速开始分词任务。此外，用户还可以共享和下载其他用户训练好的模型，节省了训练时间和资源。
#
# 使用SentencePiece进行分词的一般流程如下：
#
# 1. 准备训练数据：收集并准备用于训练的原始文本数据，可以是未经分词的文本。
#
# 1. 训练模型：使用SentencePiece提供的API，将原始文本数据作为输入进行模型训练。可以选择合适的分词算法和训练参数。
#
# 1. 应用模型：将训练好的模型应用于实际的分词任务。可以将模型加载到相关的NLP应用中，或使用SentencePiece提供的API进行分词操作。

# %% [markdown]
# ### 安装库和数据准备
#
# 我们在这个示例中使用一个小的训练语料(红楼梦.txt)

# %%
#仔细检查下自己的运行目录，相对路径需要注意下。
# !pwd

# %%
# ! pip install sentencepiece

# !wget https://github.com/shjwudp/shu/raw/master/books/红楼梦.txt  -P ../data

# %% [markdown]
# ### 端到端示例

# %%
# pip3 install sentencepiece  -i https://pypi.tuna.tsinghua.edu.cn/simple
import sentencepiece as spm

# 用红楼梦.txt训练一个sentencepiece模型，模型前缀model_prefix=meng, 会生成meng.model, meng.vocab.
# meng.vocab仅仅是一个参考，在分词中并未使用。
spm.SentencePieceTrainer.train('--input=../data/红楼梦.txt --model_prefix=meng_sp --vocab_size=15000')

# 实例化一个分词实例，然后加载训练好的meng.model
sp = spm.SentencePieceProcessor()
sp.load('meng_sp.model')

# encode: text => id
print(sp.encode_as_pieces('满纸荒唐言，一把辛酸泪！都云作者痴，谁解其中味？'))
print(sp.encode_as_ids('满纸荒唐言，一把辛酸泪！都云作者痴，谁解其中味？'))

# decode: id => text
print(sp.decode_pieces(['满', '纸', '荒', '唐', '言', ',', '一把', '辛', '酸', '泪']))
print(sp.decode_ids([368, 711, 2140, 2215, 244, 3, 1725, 3315, 1797, 477]))
# Out:
# ['▁', '满纸', '荒唐', '言', ',', '一把', '辛酸', '泪', '!', '都', '云', '作', '者', '痴', ',', '谁', '解', '其中', '味', '?']
# [31, 10899, 7751, 300, 3, 2007, 13055, 750, 30, 34, 379, 105, 251, 1377, 3, 170, 471, 2429, 2447, 23]
# 满纸荒唐言,一把辛酸泪
# 红想来园子闹了病,昏回话偏生灯
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=../data/红楼梦.txt --model_prefix=meng_sp --vocab_size=15000
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ../data/红楼梦.txt
#   input_format:
#   model_prefix: meng_sp
#   model_type: UNIGRAM
#   vocab_size: 15000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: ../data/红楼梦.txt
# trainer_interface.cc(378) LOG(WARNING) Found too long line (4224 > 4192).
# trainer_interface.cc(380) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(381) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(407) LOG(INFO) Loaded all 3144 sentences
# trainer_interface.cc(414) LOG(INFO) Skipped 6 too long sentences.
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=866703
# trainer_interface.cc(548) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=3986
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 3144 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=235777
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 118693 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 3144
# trainer_interface.cc(608) LOG(INFO) Done! 3395
# unigram_model_trainer.cc(564) LOG(INFO) Using 3395 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=73905 obj=1142.99 num_tokens=438712 num_tokens/piece=5.93616
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=67679 obj=1080.79 num_tokens=440306 num_tokens/piece=6.5058
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=50658 obj=1100.06 num_tokens=456624 num_tokens/piece=9.01386
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=50473 obj=1093.13 num_tokens=456736 num_tokens/piece=9.04912
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=37843 obj=1118.45 num_tokens=476595 num_tokens/piece=12.594
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=37834 obj=1111.04 num_tokens=476662 num_tokens/piece=12.5988
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=28375 obj=1137.73 num_tokens=496986 num_tokens/piece=17.5149
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=28374 obj=1130.28 num_tokens=497003 num_tokens/piece=17.5161
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=21279 obj=1158.95 num_tokens=516498 num_tokens/piece=24.2727
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=21278 obj=1152.07 num_tokens=516594 num_tokens/piece=24.2783
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=16500 obj=1178.05 num_tokens=534643 num_tokens/piece=32.4026
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=16500 obj=1172.19 num_tokens=534681 num_tokens/piece=32.4049
# trainer_interface.cc(686) LOG(INFO) Saving model: meng_sp.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: meng_sp.vocab

# %%
# 返回 vocab size
print(f"词表大小={sp.get_piece_size()}")

print(sp.encode_as_ids("宝玉"))
# id <=> piece conversion
print(sp.id_to_piece(716))
print(sp.piece_to_id('宝玉'))

# id=0的位置留着给UNK token, 可对其进行修改
print(sp.piece_to_id('__MUST_BE_UNKNOWN__'))

# 控制符 unk, <s>, </s> 默认id对应（0,1,2）
for id in range(3):
      print(sp.id_to_piece(id), sp.is_control(id))
# Out:
# 词表大小=15000
# [550]
# 收拾
# 18
# 0
# <unk> False
# <s> True
# </s> True

# %%
# 加载一个社区训练好的tokenizer对比下。

from sentencepiece import SentencePieceProcessor
model_path = "llama2enzh/tokenizer.model"
sp_model = SentencePieceProcessor(model_file=model_path)
print(f"Loaded SentencePiece model from {model_path}")

# BOS / EOS token IDs
n_words: int = sp_model.vocab_size()
bos_id: int = sp_model.bos_id()
eos_id: int = sp_model.eos_id()
pad_id: int = sp_model.pad_id()
unk_id: int = sp_model.unk_id()
print(f"#words: {n_words} - BOS ID: {bos_id} - EOS ID: {eos_id} - PAD ID: {pad_id} - UNK ID : {unk_id}")


model_path = "meng_sp.model"
sp_model = SentencePieceProcessor(model_file=model_path)
print(f"Loaded SentencePiece model from {model_path}")

# BOS / EOS token IDs
n_words: int = sp_model.vocab_size()
bos_id: int = sp_model.bos_id()
eos_id: int = sp_model.eos_id()
pad_id: int = sp_model.pad_id()
print(f"#words: {n_words} - BOS ID: {bos_id} - EOS ID: {eos_id} - PAD ID: {pad_id} - UNK ID : {unk_id}")
# Out:
# Loaded SentencePiece model from llama2enzh/tokenizer.model
# #words: 55296 - BOS ID: 1 - EOS ID: 2 - PAD ID: -1 - UNK ID : 0
# Loaded SentencePiece model from meng_sp.model
# #words: 15000 - BOS ID: 1 - EOS ID: 2 - PAD ID: -1 - UNK ID : 0

# %% [markdown]
# ### 修改这些控制符的位置
#
#
# 默认情况, UNK/BOS/EOS/PAD 这些token的是按照如下定义的:
#
# |token|UNK|BOS|EOS|PAD|
# ---|---
# |surface|&lt;unk&gt;|&lt;s&gt;|&lt;/s&gt;|&lt;pad&gt;|
# |id|0|1|2|undefined (-1)|
#
#
# 我们可以通过这些参数对齐修改 **--{unk|bos|eos|pad}_id** and **--{unk|bos|eos|pad}_piece** flags.

# %%
spm.SentencePieceTrainer.train('--input=../data/红楼梦.txt --model_prefix=meng_sp --vocab_size=5000 --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3 --pad_piece=[PAD] --unk_piece=[UNK] --bos_piece=[BOS] --eos_piece=[EOS]')
sp = spm.SentencePieceProcessor()
sp.load('meng_sp.model')

for id in range(4):
    print(sp.id_to_piece(id), sp.is_control(id))

n_words: int = sp.vocab_size()
bos_id: int = sp.bos_id()
eos_id: int = sp.eos_id()
pad_id: int = sp.pad_id()
print(f"#words: {n_words} - BOS ID: {bos_id} - EOS ID: {eos_id} - PAD ID: {pad_id} - UNK ID : {unk_id}")
# Out:
# [PAD] True
# [UNK] False
# [BOS] True
# [EOS] True
# #words: 5000 - BOS ID: 2 - EOS ID: 3 - PAD ID: 0 - UNK ID : 0
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=../data/红楼梦.txt --model_prefix=meng_sp --vocab_size=5000 --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3 --pad_piece=[PAD] --unk_piece=[UNK] --bos_piece=[BOS] --eos_piece=[EOS]
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ../data/红楼梦.txt
#   input_format:
#   model_prefix: meng_sp
#   model_type: UNIGRAM
#   vocab_size: 5000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: [UNK]
#   bos_piece: [BOS]
#   eos_piece: [EOS]
#   pad_piece: [PAD]
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: ../data/红楼梦.txt
# trainer_interface.cc(378) LOG(WARNING) Found too long line (4224 > 4192).
# trainer_interface.cc(380) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(381) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(407) LOG(INFO) Loaded all 3144 sentences
# trainer_interface.cc(414) LOG(INFO) Skipped 6 too long sentences.
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [UNK]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=866703
# trainer_interface.cc(548) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=3986
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 3144 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=235777
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 118693 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 3144
# trainer_interface.cc(608) LOG(INFO) Done! 3395
# unigram_model_trainer.cc(564) LOG(INFO) Using 3395 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=73905 obj=1142.99 num_tokens=438712 num_tokens/piece=5.93616
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=67679 obj=1080.79 num_tokens=440306 num_tokens/piece=6.5058
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=50658 obj=1100.06 num_tokens=456624 num_tokens/piece=9.01386
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=50473 obj=1093.13 num_tokens=456736 num_tokens/piece=9.04912
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=37843 obj=1118.45 num_tokens=476595 num_tokens/piece=12.594
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=37834 obj=1111.04 num_tokens=476662 num_tokens/piece=12.5988
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=28375 obj=1137.73 num_tokens=496986 num_tokens/piece=17.5149
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=28374 obj=1130.28 num_tokens=497003 num_tokens/piece=17.5161
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=21279 obj=1158.95 num_tokens=516498 num_tokens/piece=24.2727
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=21278 obj=1152.07 num_tokens=516594 num_tokens/piece=24.2783
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=15958 obj=1181.65 num_tokens=536979 num_tokens/piece=33.6495
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=15958 obj=1175 num_tokens=537015 num_tokens/piece=33.6518
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=11968 obj=1207.45 num_tokens=558328 num_tokens/piece=46.6517
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=11968 obj=1200.86 num_tokens=558336 num_tokens/piece=46.6524
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=8976 obj=1236.09 num_tokens=581911 num_tokens/piece=64.8297
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=8976 obj=1228.76 num_tokens=581916 num_tokens/piece=64.8302
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=6732 obj=1270.8 num_tokens=610956 num_tokens/piece=90.754
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=6732 obj=1261.38 num_tokens=610958 num_tokens/piece=90.7543
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=5500 obj=1299.15 num_tokens=638079 num_tokens/piece=116.014
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=5500 obj=1290.19 num_tokens=638079 num_tokens/piece=116.014
# trainer_interface.cc(686) LOG(INFO) Saving model: meng_sp.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: meng_sp.vocab

# %% [markdown]
# ### BPE (Byte pair encoding) model
#
# 可通过 -model_type=bpe 指定model类型

# %%
import sentencepiece as spm
spm.SentencePieceTrainer.train('--input=../data/红楼梦.txt --model_prefix=meng_bpe --vocab_size=15000 --model_type=bpe')
sp_bpe = spm.SentencePieceProcessor()
sp_bpe.load('meng_bpe.model')

print('*** BPE ***')
print(sp_bpe.encode_as_pieces('满纸荒唐言，一把辛酸泪'))
print(sp_bpe.nbest_encode_as_pieces('满纸荒唐言', 5))  # returns an empty list.

# encode: text => id
print(sp_bpe.encode_as_pieces('满纸荒唐言，一把辛酸泪！都云作者痴，谁解其中味？'))
print(sp_bpe.encode_as_ids('满纸荒唐言，一把辛酸泪！都云作者痴，谁解其中味？'))

# decode: id => text
print(sp_bpe.decode_pieces(['满', '纸', '荒', '唐', '言', ',', '一把', '辛', '酸', '泪']))
print(sp_bpe.decode_ids([6060, 6407, 6679, 7346, 7398, 6260, 6014, 983, 7319, 7195, 6353]))
# Out:
# *** BPE ***
# ['▁', '满纸', '荒唐', '言', ',', '一把', '辛', '酸', '泪']
# []
# ['▁', '满纸', '荒唐', '言', ',', '一把', '辛', '酸', '泪', '!', '都', '云', '作', '者', '痴', ',', '谁', '解', '其中', '味', '?']
# [11060, 10875, 6877, 11260, 11014, 984, 12319, 12195, 11353, 11071, 11073, 11222, 11146, 11319, 11793, 11014, 11185, 11328, 1837, 11853, 11051]
# 满纸荒唐言,一把辛酸泪
# 现是昨儿晚上小螺乱跳共总她怎么无非凤姐儿笑道不期但只一件问是谁
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=../data/红楼梦.txt --model_prefix=meng_bpe --vocab_size=15000 --model_type=bpe
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ../data/红楼梦.txt
#   input_format:
#   model_prefix: meng_bpe
#   model_type: BPE
#   vocab_size: 15000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: ../data/红楼梦.txt
# trainer_interface.cc(378) LOG(WARNING) Found too long line (4224 > 4192).
# trainer_interface.cc(380) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(381) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(407) LOG(INFO) Loaded all 3144 sentences
# trainer_interface.cc(414) LOG(INFO) Skipped 6 too long sentences.
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=866703
# trainer_interface.cc(548) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=3986
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 3144 sentences.
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 3144
# trainer_interface.cc(608) LOG(INFO) Done! 3395
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10909 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1062 size=20 all=142700 active=13121 piece=宝钗
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=830 size=40 all=148806 active=19227 piece=不是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=557 size=60 all=155070 active=25491 piece=姐姐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=439 size=80 all=159890 active=30311 piece=探春
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=366 size=100 all=164226 active=34647 piece=今日
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=365 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=309 size=120 all=168028 active=11776 piece=打发
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=267 size=140 all=171478 active=15226 piece=到了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=237 size=160 all=174367 active=18115 piece=明儿
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=220 size=180 all=177702 active=21450 piece=小厮
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=204 size=200 all=180358 active=24106 piece=跟前
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=203 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=192 size=220 all=182756 active=11283 piece=一声
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=179 size=240 all=185403 active=13930 piece=叫我
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=170 size=260 all=187764 active=16291 piece=不必
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=160 size=280 all=189938 active=18465 piece=不要
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=300 all=192342 active=20869 piece=妙玉
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=153 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=144 size=320 all=194401 active=11557 piece=二十
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=136 size=340 all=196500 active=13656 piece=服侍
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=132 size=360 all=198690 active=15846 piece=衣服
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=127 size=380 all=200579 active=17735 piece=年纪
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=123 size=400 all=202632 active=19788 piece=祖宗
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=123 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=118 size=420 all=204459 active=11872 piece=不过是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=113 size=440 all=206236 active=13649 piece=将来
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=109 size=460 all=208051 active=15464 piece=给你
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=480 all=209511 active=16924 piece=便道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=101 size=500 all=210991 active=18404 piece=了些
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=101 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=98 size=520 all=212650 active=12105 piece=说我
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=94 size=540 all=214259 active=13714 piece=好生
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=91 size=560 all=215772 active=15227 piece=着一
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=88 size=580 all=217267 active=16722 piece=伤心
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=600 all=218758 active=18213 piece=不去
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=85 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=620 all=220299 active=12414 piece=道士
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=81 size=640 all=221783 active=13898 piece=又命
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=78 size=660 all=223114 active=15229 piece=也不用
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=75 size=680 all=224457 active=16572 piece=不提
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=700 all=225798 active=17913 piece=记得
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=74 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=720 all=227109 active=12535 piece=出来了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=69 size=740 all=228333 active=13759 piece=打量
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=760 all=229530 active=14956 piece=到底是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=780 all=230537 active=15963 piece=中用
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=800 all=231536 active=16962 piece=忙问
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=65 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=820 all=232604 active=12606 piece=》,
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=840 all=233668 active=13670 piece=却说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=860 all=234799 active=14801 piece=地里
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=880 all=235929 active=15931 piece=后面
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=900 all=237139 active=17141 piece=也未
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=59 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=920 all=238161 active=12856 piece=放了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=57 size=940 all=239206 active=13901 piece=还说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=960 all=240244 active=14939 piece=大太太
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=980 all=241377 active=16072 piece=笑起来
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=53 size=1000 all=242326 active=17021 piece=一块
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=53 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=1020 all=243300 active=13029 piece=倒像
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=1040 all=244152 active=13881 piece=一场
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=1060 all=245149 active=14878 piece=怎么说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=1080 all=245965 active=15694 piece=轻轻
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=1100 all=246845 active=16574 piece=受用
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=49 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=1120 all=247733 active=13201 piece=那婆子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=1140 all=248574 active=14042 piece=园子里
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=1160 all=249565 active=15033 piece=是了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=1180 all=250164 active=15632 piece=丰儿
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=1200 all=250953 active=16421 piece=再来
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=45 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=1220 all=251817 active=13373 piece=贾珍道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=1240 all=252700 active=14256 piece=认真
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=1260 all=253545 active=15101 piece=放着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=1280 all=254358 active=15914 piece=四五
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=1300 all=255263 active=16819 piece=不自在
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=42 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=1320 all=256061 active=13533 piece=立刻
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=1340 all=256674 active=14146 piece=一番
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=1360 all=257558 active=15030 piece=张华
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=1380 all=258282 active=15754 piece=那里去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=1400 all=258984 active=16456 piece=忙着
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=39 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=1420 all=259738 active=13651 piece=人多
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=1440 all=260551 active=14464 piece=他两个
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=1460 all=261338 active=15251 piece=大舅
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=1480 all=262108 active=16021 piece=这可
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=1500 all=262710 active=16623 piece=倒了
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=36 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=1520 all=263435 active=13829 piece=王仁
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=1540 all=264182 active=14576 piece=为的是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=1560 all=264985 active=15379 piece=乃是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=1580 all=265760 active=16154 piece=秋桐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=1600 all=266348 active=16742 piece=......”
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=34 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=1620 all=267083 active=14049 piece=朋友
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=1640 all=267769 active=14735 piece=怎么就
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=1660 all=268468 active=15434 piece=取了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=1680 all=269142 active=16108 piece=等语
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=1700 all=269848 active=16814 piece=这些东西
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=32 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=1720 all=270491 active=14102 piece=念道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=1740 all=271184 active=14795 piece=▁一日
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=1760 all=271767 active=15378 piece=之家
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=1780 all=272394 active=16005 piece=女婿
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=1800 all=273103 active=16714 piece=闹出
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=31 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=1820 all=273701 active=14223 piece=琏二奶奶
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=1840 all=274263 active=14785 piece=大娘
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=1860 all=274943 active=15465 piece=知县
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=1880 all=275552 active=16074 piece=李纨笑道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=1900 all=276164 active=16686 piece=左右
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=29 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=1920 all=276823 active=14435 piece=金银
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=1940 all=277524 active=15136 piece=这边来
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=1960 all=278091 active=15703 piece=劝解
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=1980 all=278696 active=16308 piece=李十
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=2000 all=279346 active=16958 piece=众姊妹
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=28 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=2020 all=279803 active=14388 piece=乱嚷
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=2040 all=280360 active=14945 piece=打着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=2060 all=280960 active=15545 piece=这件
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=2080 all=281532 active=16117 piece=个好
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=2100 all=282103 active=16688 piece=彩屏
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=26 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=2120 all=282626 active=14611 piece=派了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=2140 all=283134 active=15119 piece=叫我们
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2160 all=283664 active=15649 piece=为我
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2180 all=284227 active=16212 piece=娶亲
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2200 all=284779 active=16764 piece=的病
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=25 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2220 all=285348 active=14773 piece=二老爷
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2240 all=285926 active=15351 piece=笑嘻嘻的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=2260 all=286425 active=15850 piece=打起
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=2280 all=286963 active=16388 piece=跑到
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=2300 all=287473 active=16898 piece=贾政等
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=24 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2320 all=287914 active=14790 piece=及至
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2340 all=288481 active=15357 piece=成日
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2360 all=288990 active=15866 piece=离了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2380 all=289487 active=16363 piece=在炕上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2400 all=289944 active=16820 piece=也是有的
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=23 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2420 all=290348 active=14892 piece=便也
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2440 all=290855 active=15399 piece=张三
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2460 all=291363 active=15907 piece=皆因
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2480 all=291846 active=16390 piece=领了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2500 all=292276 active=16820 piece=没要紧
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=22 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2520 all=292626 active=14949 piece=!“
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2540 all=293052 active=15375 piece=再要
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2560 all=293583 active=15906 piece=归坐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2580 all=294040 active=16363 piece=的很
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2600 all=294491 active=16814 piece=镜子
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2620 all=294955 active=15162 piece=成日家
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2640 all=295375 active=15582 piece=一面说着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2660 all=295723 active=15930 piece=了脸
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2680 all=296161 active=16368 piece=婶婶
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2700 all=296578 active=16785 piece=机会
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2720 all=297058 active=15296 piece=贾敬
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2740 all=297475 active=15713 piece=你心里
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2760 all=297895 active=16133 piece=的样子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2780 all=298294 active=16532 piece=一言
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2800 all=298714 active=16952 piece=入画
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2820 all=299099 active=15300 piece=固然
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2840 all=299509 active=15710 piece=性子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2860 all=299941 active=16142 piece=没良
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2880 all=300372 active=16573 piece=诰命
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2900 all=300799 active=17000 piece=不用说
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2920 all=301191 active=15415 piece=我和你
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2940 all=301548 active=15772 piece=不是别人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2960 all=301767 active=15991 piece=不一
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2980 all=302131 active=16355 piece=你家
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=3000 all=302571 active=16795 piece=另外
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=3020 all=302976 active=15506 piece=张家
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=3040 all=303374 active=15904 piece=泪痕
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=3060 all=303786 active=16316 piece=詹光
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=3080 all=304169 active=16699 piece=书房里
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=3100 all=304527 active=17057 piece=暗暗的
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=3120 all=304869 active=15542 piece=说了出来
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3140 all=305216 active=15889 piece=之上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3160 all=305592 active=16265 piece=出家
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3180 all=305963 active=16636 piece=天恩
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3200 all=306347 active=17020 piece=接过
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3220 all=306757 active=15701 piece=若干
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3240 all=307124 active=16068 piece=金刚
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3260 all=307421 active=16365 piece=你们都
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3280 all=307760 active=16704 piece=没有人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=3300 all=308094 active=17038 piece=听见这话
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3320 all=308358 active=15655 piece=丸药
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3340 all=308718 active=16015 piece=原委
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3360 all=309098 active=16395 piece=得着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3380 all=309492 active=16789 piece=气了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3400 all=309865 active=17162 piece=袄儿
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=16 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3420 all=310243 active=15854 piece=鬼祟
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3440 all=310539 active=16150 piece=听这话
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3460 all=310868 active=16479 piece=椅子上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=3480 all=311179 active=16790 piece=众人听说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3500 all=311471 active=17082 piece=一问
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3520 all=311803 active=15893 piece=关门
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3540 all=312154 active=16244 piece=可有
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3560 all=312481 active=16571 piece=将就
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3580 all=312820 active=16910 piece=我劝
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3600 all=313181 active=17271 piece=有钱
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3620 all=313552 active=16012 piece=省些
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3640 all=313846 active=16306 piece=茯苓
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3660 all=314224 active=16684 piece=香袋
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3680 all=314503 active=16963 piece=便有些
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3700 all=314849 active=17309 piece=我出去
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3720 all=315152 active=16030 piece=过日子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3740 all=315432 active=16310 piece=吓了一跳
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3760 all=315623 active=16501 piece=三千
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3780 all=315954 active=16832 piece=书子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3800 all=316278 active=17156 piece=冷了
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=14 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3820 all=316628 active=16152 piece=喜的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3840 all=316932 active=16456 piece=安了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3860 all=317230 active=16754 piece=快别
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3880 all=317554 active=17078 piece=新奇
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3900 all=317874 active=17398 piece=真正
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=14 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3920 all=318195 active=16197 piece=要死
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3940 all=318511 active=16513 piece=馒头
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3960 all=318801 active=16803 piece=你奶奶
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3980 all=319122 active=17124 piece=宝蟾道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=4000 all=319416 active=17418 piece=说得是
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=14 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=4020 all=319654 active=16200 piece=回了太太
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=4040 all=319883 active=16429 piece=还是这么
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4060 all=320085 active=16631 piece=不迟
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4080 all=320401 active=16947 piece=你吃
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4100 all=320726 active=17272 piece=办去
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4120 all=320991 active=16289 piece=围屏
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4140 all=321326 active=16624 piece=少了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4160 all=321622 active=16920 piece=打她
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4180 all=321923 active=17221 piece=有此
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4200 all=322243 active=17541 piece=王氏
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4220 all=322500 active=16358 piece=给人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4240 all=322788 active=16646 piece=跟随
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4260 all=323058 active=16916 piece=。――
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4280 all=323303 active=17161 piece=了什么
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4300 all=323583 active=17441 piece=和平儿
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4320 all=323826 active=16403 piece=我母亲
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4340 all=324123 active=16700 piece=自己却
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4360 all=324406 active=16983 piece=麝月等
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=4380 all=324602 active=17179 piece=给老太��
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4400 all=324844 active=17421 piece=不离
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4420 all=325093 active=16473 piece=人间
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4440 all=325360 active=16740 piece=别是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4460 all=325651 active=17031 piece=唠叨
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4480 all=325911 active=17291 piece=好笑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4500 all=326194 active=17574 piece=床前
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4520 all=326452 active=16559 piece=换上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4540 all=326764 active=16871 piece=模糊
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4560 all=327067 active=17174 piece=疼得
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4580 all=327371 active=17478 piece=舌头
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4600 all=327647 active=17754 piece=远近
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4620 all=327906 active=16627 piece=》。”
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4640 all=328151 active=16872 piece=便叫人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4660 all=328393 active=17114 piece=妈妈们
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4680 all=328660 active=17381 piece=漱了口
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4700 all=328921 active=17642 piece=这一日
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4720 all=329116 active=16630 piece=太虚幻境
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=4740 all=329306 active=16820 piece=身上不好
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4760 all=329480 active=16994 piece=下手
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4780 all=329731 active=17245 piece=众位
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4800 all=329983 active=17497 piece=冷眼
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4820 all=330239 active=16738 piece=可好
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4840 all=330482 active=16981 piece=失手
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4860 all=330759 active=17258 piece=带他
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4880 all=330998 active=17497 piece=或可
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4900 all=331282 active=17781 piece=有我
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4920 all=331546 active=16815 piece=疼痛
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4940 all=331805 active=17074 piece=等类
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4960 all=332044 active=17313 piece=行动
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=4980 all=332277 active=17546 piece=轻易
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5000 all=332552 active=17821 piece=隐隐
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5020 all=332775 active=16838 piece=一干人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5040 all=332998 active=17061 piece=也算是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5060 all=333231 active=17294 piece=哪里去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5080 all=333461 active=17524 piece=就这样
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5100 all=333682 active=17745 piece=是有的
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5120 all=333938 active=16929 piece=给她们
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5140 all=334191 active=17182 piece=还有谁
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5160 all=334406 active=17397 piece=你也不用
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=5180 all=334600 active=17591 piece=笑个不住
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5200 all=334725 active=17716 piece=一分
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5220 all=334972 active=16971 piece=东南
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5240 all=335207 active=17206 piece=他作
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5260 all=335435 active=17434 piece=依然
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5280 all=335682 active=17681 piece=写的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5300 all=335917 active=17916 piece=半月
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5320 all=336155 active=17021 piece=合眼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5340 all=336375 active=17241 piece=奚落
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5360 all=336626 active=17492 piece=就去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5380 all=336866 active=17732 piece=性格
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5400 all=337123 active=17989 piece=把手
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5420 all=337379 active=17099 piece=旧诗
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5440 all=337597 active=17317 piece=检点
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5460 all=337820 active=17540 piece=狠狠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5480 all=338057 active=17777 piece=知的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5500 all=338284 active=18004 piece=花草
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5520 all=338529 active=17146 piece=该班
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5540 all=338761 active=17378 piece=递了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5560 all=338977 active=17594 piece=▁晴雯
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5580 all=339187 active=17804 piece=他也不
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5600 all=339374 active=17991 piece=出这个
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5620 all=339603 active=17183 piece=哪里就
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5640 all=339819 active=17399 piece=就来了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5660 all=340040 active=17620 piece=提醒了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5680 all=340266 active=17846 piece=画着一
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5700 all=340496 active=18076 piece=说一句
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5720 all=340672 active=17187 piece=项银子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5740 all=340825 active=17340 piece=告诉了他
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5760 all=340983 active=17498 piece=是怎么样
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=5780 all=341125 active=17640 piece=还不知道呢
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5800 all=341303 active=17818 piece=不以
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5820 all=341519 active=17269 piece=也自
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5840 all=341726 active=17476 piece=你都
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5860 all=341929 active=17679 piece=几杯
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5880 all=342115 active=17865 piece=发烧
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5900 all=342340 active=18090 piece=呆了
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5920 all=342539 active=17307 piece=大胆
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5940 all=342745 active=17513 piece=家业
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5960 all=342975 active=17743 piece=帕子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=5980 all=343198 active=17966 piece=感冒
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6000 all=343416 active=18184 piece=掀帘
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6020 all=343627 active=17371 piece=望候
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6040 all=343843 active=17587 piece=求亲
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6060 all=344067 active=17811 piece=理论
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6080 all=344258 active=18002 piece=着个
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6100 all=344486 active=18230 piece=红毡
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6120 all=344708 active=17437 piece=莫非
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6140 all=344910 active=17639 piece=请去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6160 all=345112 active=17841 piece=问时
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6180 all=345257 active=17986 piece=一点子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6200 all=345442 active=18171 piece=二人方
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6220 all=345632 active=17452 piece=依你说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6240 all=345821 active=17641 piece=叫鸳鸯
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6260 all=346051 active=17871 piece=如今也
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6280 all=346240 active=18060 piece=恐贾母
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6300 all=346406 active=18226 piece=是正经
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6320 all=346574 active=17480 piece=第二日
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6340 all=346745 active=17651 piece=这一番
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6360 all=346932 active=17838 piece=不必细说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6380 all=347078 active=17984 piece=商议定了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6400 all=347241 active=18147 piece=我的东西
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6420 all=347383 active=17496 piece=袭人见他
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=6440 all=347519 active=17632 piece=是什么意思
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6460 all=347686 active=17799 piece=三首
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6480 all=347881 active=17994 piece=为你
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6500 all=348066 active=18179 piece=亏空
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6520 all=348255 active=17583 piece=作怪
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6540 all=348422 active=17750 piece=入宫
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6560 all=348602 active=17930 piece=划拳
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6580 all=348789 active=18117 piece=又生
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6600 all=348967 active=18295 piece=吊子
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6620 all=349151 active=17623 piece=四回
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6640 all=349338 active=17810 piece=太君
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6660 all=349515 active=17987 piece=实的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6680 all=349706 active=18178 piece=尸首
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6700 all=349890 active=18362 piece=当槽
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6720 all=350039 active=17635 piece=戏文
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6740 all=350250 active=17846 piece=探头
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6760 all=350435 active=18031 piece=无味
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6780 all=350604 active=18200 piece=杜撰
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6800 all=350794 active=18390 piece=沿上
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6820 all=350970 active=17710 piece=用话
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6840 all=351165 active=17905 piece=看到
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6860 all=351346 active=18086 piece=纵有
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6880 all=351524 active=18264 piece=藏着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6900 all=351704 active=18444 piece=费了
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6920 all=351886 active=17756 piece=逛去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6940 all=352053 active=17923 piece=零碎
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6960 all=352218 active=18088 piece=下剩的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=6980 all=352401 active=18271 piece=交给我
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7000 all=352562 active=18432 piece=便笑着
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7020 all=352724 active=17783 piece=口气道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7040 all=352882 active=17941 piece=嗳哟哟
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7060 all=353043 active=18102 piece=如有所
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7080 all=353212 active=18271 piece=忍不住
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7100 all=353371 active=18430 piece=我素日
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7120 all=353551 active=17838 piece=正二刻
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7140 all=353720 active=18007 piece=给二爷
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7160 all=353896 active=18183 piece=走来说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7180 all=354063 active=18350 piece=那大夫
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7200 all=354188 active=18475 piece=口内说道
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7220 all=354284 active=17805 piece=心中自是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7240 all=354413 active=17934 piece=暂且不提
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7260 all=354553 active=18074 piece=说说笑笑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=7280 all=354653 active=18174 piece=不觉红了脸
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7300 all=354777 active=18298 piece=一觉
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7320 all=354952 active=17909 piece=与人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7340 all=355118 active=18075 piece=九回
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7360 all=355276 active=18233 piece=份例
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7380 all=355420 active=18377 piece=你能
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7400 all=355579 active=18536 piece=再定
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7420 all=355745 active=17937 piece=北边
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7440 all=355896 active=18088 piece=发笑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7460 all=356043 active=18235 piece=各种
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7480 all=356207 active=18399 piece=哭声
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7500 all=356358 active=18550 piece=坐席
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7520 all=356523 active=17976 piece=头晕
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7540 all=356692 active=18145 piece=孝心
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7560 all=356858 active=18311 piece=尽情
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7580 all=357017 active=18470 piece=开着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7600 all=357172 active=18625 piece=恨的
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7620 all=357328 active=18006 piece=托他
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7640 all=357490 active=18168 piece=掩住
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7660 all=357659 active=18337 piece=无疑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7680 all=357824 active=18502 piece=树下
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7700 all=358000 active=18678 piece=治死
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7720 all=358157 active=18050 piece=狮子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7740 all=358313 active=18206 piece=的娘
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7760 all=358474 active=18367 piece=祖上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7780 all=358633 active=18526 piece=第五
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7800 all=358791 active=18684 piece=美玉
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7820 all=358954 active=18095 piece=舌的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7840 all=359119 active=18260 piece=表兄
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7860 all=359274 active=18415 piece=谢礼
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7880 all=359457 active=18598 piece=还少
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7900 all=359621 active=18762 piece=重新
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7920 all=359791 active=18144 piece=难处
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7940 all=359946 active=18299 piece=鼓乐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7960 all=360087 active=18440 piece=不叫他
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=7980 all=360235 active=18588 piece=也没人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8000 all=360395 active=18748 piece=人进来
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8020 all=360531 active=18149 piece=你说说
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8040 all=360662 active=18280 piece=十二两
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8060 all=360829 active=18447 piece=咱们都
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8080 all=360988 active=18606 piece=大了道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8100 all=361131 active=18749 piece=孙绍祖
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# ...
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8160 all=361535 active=18450 piece=既来了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8180 all=361691 active=18606 piece=没有的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8200 all=361853 active=18768 piece=瞧见了
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8220 all=361988 active=18221 piece=见如此
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8240 all=362116 active=18349 piece=迎上去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8260 all=362263 active=18496 piece=银子钱
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8280 all=362397 active=18630 piece=不敢作声
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8300 all=362537 active=18770 piece=倪家母女
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8320 all=362650 active=18232 piece=和薛姨妈
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8340 all=362770 active=18352 piece=宝玉自己
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8360 all=362890 active=18472 piece=放声大哭
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8380 all=363012 active=18594 piece=自是欢喜
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8400 all=363105 active=18687 piece=这一辈子
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8420 all=363208 active=18249 piece=一个老婆子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=8440 all=363285 active=18326 piece=无精打彩的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8460 all=363373 active=18414 piece=一响
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8480 all=363501 active=18542 piece=下个
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8500 all=363652 active=18693 piece=丢开
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8520 all=363790 active=18314 piece=之族
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8540 all=363925 active=18449 piece=二千
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8560 all=364066 active=18590 piece=从新
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8580 all=364207 active=18731 piece=佳节
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8600 all=364345 active=18869 piece=倒去
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8620 all=364489 active=18355 piece=共是
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8640 all=364623 active=18489 piece=几间
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8660 all=364761 active=18627 piece=劝劝
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8680 all=364889 active=18755 piece=压压
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8700 all=365019 active=18885 piece=发起
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8720 all=365149 active=18372 piece=吃醋
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8740 all=365271 active=18494 piece=嘁嘁
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8760 all=365414 active=18637 piece=外罩
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8780 all=365545 active=18768 piece=太多
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8800 all=365673 active=18896 piece=字画
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8820 all=365804 active=18405 piece=小器
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8840 all=365921 active=18522 piece=已出
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8860 all=366064 active=18665 piece=得出
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8880 all=366205 active=18806 piece=恹恹
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8900 all=366315 active=18916 piece=才往
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8920 all=366477 active=18472 piece=拷问
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8940 all=366637 active=18632 piece=收的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8960 all=366758 active=18753 piece=日用
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=8980 all=366904 active=18899 piece=杯盘
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9000 all=367037 active=19032 piece=每一
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9020 all=367177 active=18487 piece=满怀
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9040 all=367311 active=18621 piece=狠了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9060 all=367450 active=18760 piece=癞头
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9080 all=367598 active=18908 piece=相验
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9100 all=367736 active=19046 piece=秋水
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9120 all=367863 active=18508 piece=粗细
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9140 all=367989 active=18634 piece=老三
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9160 all=368127 active=18772 piece=花朵
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9180 all=368274 active=18919 piece=衰草
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9200 all=368421 active=19066 piece=许你
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9220 all=368542 active=18533 piece=赏脸
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9240 all=368688 active=18679 piece=过意
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9260 all=368829 active=18820 piece=道路
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9280 all=368969 active=18960 piece=闲人
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9300 all=369095 active=19086 piece=风炉
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9320 all=369209 active=18560 piece=一进门
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9340 all=369328 active=18679 piece=两杯酒
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9360 all=369444 active=18795 piece=了我来
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9380 all=369550 active=18901 piece=今儿我
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9400 all=369662 active=19013 piece=你们快
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9420 all=369755 active=18571 piece=便走到
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9440 all=369877 active=18693 piece=出门的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9460 all=370001 active=18817 piece=去不成
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9480 all=370113 active=18929 piece=叫紫鹃
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9500 all=370238 active=19054 piece=和姑娘
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9520 all=370357 active=18621 piece=在怀内
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9540 all=370489 active=18753 piece=好嫂子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9560 all=370603 active=18867 piece=就死了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9580 all=370744 active=19008 piece=���下暗
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9600 all=370863 active=19127 piece=我也有
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9620 all=370978 active=18652 piece=拍着手
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9640 all=371107 active=18781 piece=柳嫂子
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9660 all=371215 active=18889 piece=琏二叔
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9680 all=371355 active=19029 piece=相好的
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9700 all=371454 active=19128 piece=给人家
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9720 all=371576 active=18686 piece=见他们
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9740 all=371695 active=18805 piece=赶不上
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9760 all=371825 active=18935 piece=这些小
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9780 all=371938 active=19048 piece=那贾琏
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9800 all=372050 active=19160 piece=▁宝玉因
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9820 all=372142 active=18689 piece=不知何事
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9840 all=372245 active=18792 piece=人命官司
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9860 all=372333 active=18880 piece=勉强笑道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9880 all=372428 active=18975 piece=听到那里
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9900 all=372529 active=19076 piece=太太说了
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9920 all=372607 active=18704 piece=岫烟笑道
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9940 all=372688 active=18785 piece=成个什么
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9960 all=372789 active=18886 piece=有凤来仪
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=9980 all=372856 active=18953 piece=络绎不绝
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=10000 all=372924 active=19021 piece=贾政听说
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=10020 all=373009 active=18732 piece=连老太太
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=10040 all=373076 active=18799 piece=倘或老太太
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=10060 all=373147 active=18870 piece=答应了出去
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10080 all=373223 active=18946 piece=!‘
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10100 all=373271 active=18994 piece=一摸
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10120 all=373381 active=18769 piece=上髟
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10140 all=373479 active=18867 piece=不挑
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10160 all=373592 active=18980 piece=两腮
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10180 all=373701 active=19089 piece=乖僻
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10200 all=373822 active=19210 piece=了腰
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10220 all=373926 active=18792 piece=京营
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10240 all=374042 active=18908 piece=他有
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10260 all=374154 active=19020 piece=传至
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10280 all=374266 active=19132 piece=依你
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10300 all=374377 active=19243 piece=先用
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10320 all=374497 active=18832 piece=内阁
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10340 all=374607 active=18942 piece=凸碧
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10360 all=374721 active=19056 piece=刻丝
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10380 all=374836 active=19171 piece=危急
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10400 all=374955 active=19290 piece=反被
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10420 all=375067 active=18855 piece=叫那
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10440 all=375171 active=18959 piece=吊着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10460 all=375282 active=19070 piece=哭呢
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10480 all=375380 active=19168 piece=在坐
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10500 all=375480 active=19268 piece=大车
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10520 all=375583 active=18876 piece=好诗
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10540 all=375689 active=18982 piece=完结
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10560 all=375808 active=19101 piece=导引
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10580 all=375916 active=19209 piece=展开
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10600 all=376024 active=19317 piece=底细
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10620 all=376143 active=18917 piece=很该
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10640 all=376269 active=19043 piece=快打
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10660 all=376379 active=19153 piece=悬着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10680 all=376497 active=19271 piece=打一
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10700 all=376610 active=19384 piece=报仇
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10720 all=376730 active=18944 piece=挂念
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10740 all=376843 active=19057 piece=搁着
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10760 all=376963 active=19177 piece=敬服
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10780 all=377071 active=19285 piece=春花
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10800 all=377198 active=19412 piece=朝上
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10820 all=377320 active=18973 piece=柴胡
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10840 all=377426 active=19079 piece=母珠
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10860 all=377546 active=19199 piece=浮躁
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10880 all=377663 active=19316 piece=熬了
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10900 all=377773 active=19426 piece=甘露
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10920 all=377896 active=19005 piece=的旧
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10940 all=378001 active=19110 piece=眼内
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10960 all=378132 active=19241 piece=碗箸
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=10980 all=378239 active=19348 piece=称扬
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=11000 all=378360 active=19469 piece=粗笨
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=2
# trainer_interface.cc(686) LOG(INFO) Saving model: meng_bpe.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: meng_bpe.vocab

# %%
unigram 概率
['▁', '满纸', '荒唐', '言', ',', '一把', '辛酸', '泪', '!', '都', '云', '作', '者', '痴', ',', '谁', '解', '其中', '味', '?']
bpe 频率
['▁', '满纸', '荒唐', '言', ',', '一把', '辛', '酸', '泪', '!', '都', '云', '作', '者', '痴', ',', '谁', '解', '其中', '味', '?']
